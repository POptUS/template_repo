# %% [markdown]
# # My Example Title

# %% [markdown]
# This can be general text that is meant for inclusion in the examples Jupyter book.  We can explain what the notebook does and how to use it appropriately.  The next cell contains example code that demonstrates how to use the code.  It should also be rendered in the book.

# %%
from mytemplate import compute
from mytemplate2.subC import compute_c

x = 1.1
y = compute(x)
y_c = compute_c(x)

print()
print(f"compute   gave {y} for an input of {x}")
print(f"compute_c gave {y_c} for an input of {x}")
print()
# Out:
# /Users/jared/Projects/POptUS/template_repo/mytemplate_pypkg/src/mytemplate/compute.py called
#
# /Users/jared/Projects/POptUS/template_repo/subC/py/compute_c.py called
#
# compute   gave 5.5 for an input of 1.1
# compute_c gave 1.3310000000000004 for an input of 1.1

# %% [markdown]
# We can pretend that these comments summarize the results presented by the previous code cell.  It would also be included in the book.

# %% [markdown]
# This cell contains notes relevant to me and other maintainers so that we can understand why we designed the notebook this way and back up some of our claims.  For instance
# \\[
# 5 \cdot 1.1 = 5.5.
# \\]
#
# Since this supports the example, but does not add to the example's content from a user's perspective, the cell and its output are hidden by setting its tag to remove-cell.

# %%
# Cell and its output also hidden with remove-cell
#
# This cell contains tests that we want run every time that a user or
# Jupyter book runs this notebook to ensure that the notebook is
# functioning correctly.  While this is obviously useful in terms
# of notebook maintenance and ensuring correct content in the book,
# it also means that such examples also function as an unofficial
# test suite.

import numpy as np

EPS = np.finfo(float).eps

assert np.fabs(1.0 - y / 5.5) <= EPS
assert np.fabs(1.0 - y_c / 1.331) <= 2.0 * EPS
